# %% [markdown]
# <a href="https://colab.research.google.com/github/Felicette1963/Python_Numpy_Colab/blob/main/2023_Python_Pandas_Review_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# 시리즈 : 인덱스 (라벨), 값
data = np.random.randint(10 ** 5, 10 ** 6, size=10)  # 10개
index = list("ABCDEFGHIJ")  # 10개
s = pd.Series(data, index=index)
s
# Out:
# A    805428
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# dtype: int64

# %%
s2 = pd.Series(data)
s2 # pd.Series(data, index=range(len(data)))
# Out:
# 0    805428
# 1    724894
# 2    315425
# 3    829995
# 4    594727
# 5    644557
# 6    975540
# 7    741387
# 8    379926
# 9    564249
# dtype: int64

# %%
s, s.index, s.values
# Out:
# (A    805428
#  B    724894
#  C    315425
#  D    829995
#  E    594727
#  F    644557
#  G    975540
#  H    741387
#  I    379926
#  J    564249
#  dtype: int64,
#  Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object'),
#  array([805428, 724894, 315425, 829995, 594727, 644557, 975540, 741387,
#         379926, 564249]))

# %%
s.index.name = "코드"
s.name = "통계"
s
# Out:
# 코드
# A    805428
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
s + 100, s - 100, s * 100
# Out:
# (코드
#  A    805528
#  B    724994
#  C    315525
#  D    830095
#  E    594827
#  F    644657
#  G    975640
#  H    741487
#  I    380026
#  J    564349
#  Name: 통계, dtype: int64,
#  코드
#  A    805328
#  B    724794
#  C    315325
#  D    829895
#  E    594627
#  F    644457
#  G    975440
#  H    741287
#  I    379826
#  J    564149
#  Name: 통계, dtype: int64,
#  코드
#  A    80542800
#  B    72489400
#  C    31542500
#  D    82999500
#  E    59472700
#  F    64455700
#  G    97554000
#  H    74138700
#  I    37992600
#  J    56424900
#  Name: 통계, dtype: int64)

# %% [markdown]
# # 시리즈

# %% [markdown]
# ## 인덱스, 슬라이스

# %%
s
# Out:
# 코드
# A    805428
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
s[1], s["B"], s[-1]
# Out:
# (724894, 724894, 564249)

# %%
s[[0, 4, 2, 1]]  # 리스트 형태 -> 정수 인덱스
# Out:
# 코드
# A    805428
# E    594727
# C    315425
# B    724894
# Name: 통계, dtype: int64

# %%
s[['B', 'E', 'D']]
# Out:
# 코드
# B    724894
# E    594727
# D    829995
# Name: 통계, dtype: int64

# %%
s > 500000
# Out:
# 코드
# A     True
# B     True
# C    False
# D     True
# E     True
# F     True
# G     True
# H     True
# I    False
# J     True
# Name: 통계, dtype: bool

# %%
s[s > 500000]
# Out:
# 코드
# A    805428
# B    724894
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# J    564249
# Name: 통계, dtype: int64

# %%
s[1:3]  # 끝점(X) -> 끝점을 포함하는 경우... 정수 (위치) 인덱스와 인덱스라벨 => 일치하면 => 인덱스라벨이 우선권
# Out:
# 코드
# B    724894
# C    315425
# Name: 통계, dtype: int64

# %%
s["B":"D"]  # 끝점(O) -> 인덱스 라벨
# Out:
# 코드
# B    724894
# C    315425
# D    829995
# Name: 통계, dtype: int64

# %%
s.B  # 변수로 나타낼 수 있는 문자열 (숫자로 시작하지 않고, _ 외의 특수문자가 들어가있지 않으며, 공백이 섞여있지 않으면...)
# Out:
# 724894

# %% [markdown]
# ## 딕셔너리

# %%
s
# Out:
# 코드
# A    805428
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
603519 in s  # value를 in 연산 하는게 아닌가?
# Out:
# False

# %%
"A" in s  # index로 in 연산
# Out:
# True

# %%
# index가 마치 딕셔너리의 'keys'의 역할
"A" in s, "A" in s.index
# Out:
# (True, True)

# %%
for i in s.items():
    print(i)
# Out:
# ('A', 805428)
# ('B', 724894)
# ('C', 315425)
# ('D', 829995)
# ('E', 594727)
# ('F', 644557)
# ('G', 975540)
# ('H', 741387)
# ('I', 379926)
# ('J', 564249)

# %%
for index, value in s.items():
    print(f"{index} {value}")
# Out:
# A 805428
# B 724894
# C 315425
# D 829995
# E 594727
# F 644557
# G 975540
# H 741387
# I 379926
# J 564249

# %%
# s = pd.Series(data, index=index)
# s3 = pd.Series({
#     "A": np.random.randint(10 ** 3, 10 **4),
#     "B": np.random.randint(10 ** 3, 10 **4),
#     "C": np.random.randint(10 ** 3, 10 **4),
#     "D": np.random.randint(10 ** 3, 10 **4),
# })
s3 = pd.Series({
    # key : value for 변수명 in 시퀀스
    v: np.random.randint(10 ** 3, 10 ** 4) for v in list("ABCD")
})  # 순서가 정해져있지 않기 때문에...
s3
# Out:
# A    8766
# B    8912
# C    9611
# D    6206
# dtype: int64

# %%
s3 = pd.Series({
    # key : value for 변수명 in 시퀀스
    v: np.random.randint(10 ** 3, 10 ** 4) for v in list("ABCD")
}, index=["D", "B", "C", "A"])
# index를 통해서 key값의 순서를 지정하면 -> 해당 순서대로 시리즈가 나열
s3
# Out:
# D    7900
# B    4028
# C    8490
# A    5901
# dtype: int64

# %%
a1 = pd.Series({
    v: np.random.randint(10 ** 3, 10 ** 4) for v in list("ABCD")
})
a2 = pd.Series({
    v: np.random.randint(10 ** 3, 10 ** 4) for v in list("ABCE")
})
a1, a2
# Out:
# (A    8992
#  B    9126
#  C    9679
#  D    2150
#  dtype: int64,
#  A    5906
#  B    5311
#  C    9350
#  E    5413
#  dtype: int64)

# %%
a1 - a2
# Out:
# A    3086.0
# B    3815.0
# C     329.0
# D       NaN
# E       NaN
# dtype: float64

# %%
da = a1 - a2
da
# Out:
# A    3086.0
# B    3815.0
# C     329.0
# D       NaN
# E       NaN
# dtype: float64

# %%
da[da.notnull()]
# Out:
# A    3086.0
# B    3815.0
# C     329.0
# dtype: float64

# %%
da.dropna()
# Out:
# A    3086.0
# B    3815.0
# C     329.0
# dtype: float64

# %%
s
# Out:
# 코드
# A    805428
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
s[0] = 555555
s
# Out:
# 코드
# A    555555
# B    724894
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
s['B'] = 666666
s
# Out:
# 코드
# A    555555
# B    666666
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# J    564249
# Name: 통계, dtype: int64

# %%
del s['J']
s
# Out:
# 코드
# A    555555
# B    666666
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# Name: 통계, dtype: int64

# %% [markdown]
# # 데이터프레임

# %%
# 세로로 붙은 -> 가로행들의 이름 index. 세로열들에 붙은 가로로 보여지는 이름 column index
# df = pd.DataFrame(data, index=index, columns=columns)
data = np.random.randint(10 ** 3, 10 ** 4, size=15).reshape(5, 3)
columns = list("abc".upper())  # 여기다가 순서바꿔서 넣으면 그냥 그 이름이 됩니다
index = list("ABCDE".lower())
data, columns, index
# Out:
# (array([[2745, 4801, 4907],
#         [1154, 8767, 9497],
#         [6407, 2563, 3928],
#         [4405, 8246, 1718],
#         [9217, 8115, 8923]]),
#  ['A', 'B', 'C'],
#  ['a', 'b', 'c', 'd', 'e'])

# %%
df1 = pd.DataFrame(data, index=index, columns=columns)
df1
# Out:
#       A     B     C
# a  2745  4801  4907
# b  1154  8767  9497
# c  6407  2563  3928
# d  4405  8246  1718
# e  9217  8115  8923

# %%
data = {
    index: np.random.randint(10 ** 3, 10 ** 4, size=5) for index in list("ABC")
}  # df에 딕셔너리를 넣으면 -> columns의 이름 = 키 => 새로운 키를 줄 수 없음
index = list("abcde")
columns = ['C', 'A', 'B']
# columns = ['ㄱ', 'ㄴ', 'ㄷ']  # 아예 다른 key를 넣으면 => 없다고 생각해서 NaN
# df2 = pd.DataFrame(data)
# df2 = pd.DataFrame(data, index=index)
df2 = pd.DataFrame(data, index=index, columns=columns)  # 순서를 바꿔주는데...
df2
# Out:
#       C     A     B
# a  8862  5720  6213
# b  7035  4650  1384
# c  2242  8755  4438
# d  2350  8382  4680
# e  1439  8175  5281

# %%
df1, df1.index, df1.columns, df1.values
# Out:
# (      A     B     C
#  a  2745  4801  4907
#  b  1154  8767  9497
#  c  6407  2563  3928
#  d  4405  8246  1718
#  e  9217  8115  8923,
#  Index(['a', 'b', 'c', 'd', 'e'], dtype='object'),
#  Index(['A', 'B', 'C'], dtype='object'),
#  array([[2745, 4801, 4907],
#         [1154, 8767, 9497],
#         [6407, 2563, 3928],
#         [4405, 8246, 1718],
#         [9217, 8115, 8923]]))

# %%
df1.T
# Out:
#       a     b     c     d     e
# A  2745  1154  6407  4405  9217
# B  4801  8767  2563  8246  8115
# C  4907  9497  3928  1718  8923

# %%
df1.index.name = '가게명'
df1.columns.name = '매출항목'
df1
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907
# b     1154  8767  9497
# c     6407  2563  3928
# d     4405  8246  1718
# e     9217  8115  8923

# %%
df1['A']['a'], df1['A']['a':'c'], df1['A'][0:2], df1['A']['a':'a']
# Out:
# (2745,
#  가게명
#  a    2745
#  b    1154
#  c    6407
#  Name: A, dtype: int64,
#  가게명
#  a    2745
#  b    1154
#  Name: A, dtype: int64,
#  가게명
#  a    2745
#  Name: A, dtype: int64)

# %%
df1['D'] = df1['A'] * 100
df1
# Out:
# 매출항목     A     B     C       D
# 가게명
# a     2745  4801  4907  274500
# b     1154  8767  9497  115400
# c     6407  2563  3928  640700
# d     4405  8246  1718  440500
# e     9217  8115  8923  921700

# %%
df1['D'] /= 1.5
df1['D'], df1
# Out:
# (가게명
#  a    183000.000000
#  b     76933.333333
#  c    427133.333333
#  d    293666.666667
#  e    614466.666667
#  Name: D, dtype: float64,
#  매출항목     A     B     C              D
#  가게명
#  a     2745  4801  4907  183000.000000
#  b     1154  8767  9497   76933.333333
#  c     6407  2563  3928  427133.333333
#  d     4405  8246  1718  293666.666667
#  e     9217  8115  8923  614466.666667)

# %%
del df1['D']
df1
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907
# b     1154  8767  9497
# c     6407  2563  3928
# d     4405  8246  1718
# e     9217  8115  8923

# %%
df1['A']
# Out:
# 가게명
# a    2745
# b    1154
# c    6407
# d    4405
# e    9217
# Name: A, dtype: int64

# %%
df1[['C','A']]
# Out:
# 매출항목     C     A
# 가게명
# a     4907  2745
# b     9497  1154
# c     3928  6407
# d     1718  4405
# e     8923  9217

# %%
df1['C']
# Out:
# 가게명
# a    4907
# b    9497
# c    3928
# d    1718
# e    8923
# Name: C, dtype: int64

# %%
df1[['C']]
# Out:
# 매출항목     C
# 가게명
# a     4907
# b     9497
# c     3928
# d     1718
# e     8923

# %%
# df1[0]  # KeyError: 0

# %%
df1[0:1]  # 슬라이스 -> 행 인덱싱. 열 인덱싱? => 리스트.
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907

# %%
df1["a":"b"], df1["a":"a"]
# Out:
# (매출항목     A     B     C
#  가게명
#  a     2745  4801  4907
#  b     1154  8767  9497,
#  매출항목     A     B     C
#  가게명
#  a     2745  4801  4907)

# %% [markdown]
# ## 인덱서

# %%
df1
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907
# b     1154  8767  9497
# c     6407  2563  3928
# d     4405  8246  1718
# e     9217  8115  8923

# %%
df1.loc['a']
# Out:
# 매출항목
# A    2745
# B    4801
# C    4907
# Name: a, dtype: int64

# %%
df1.loc[['a']]
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907

# %%
df1.loc[['c','a']]
# Out:
# 매출항목     A     B     C
# 가게명
# c     6407  2563  3928
# a     2745  4801  4907

# %%
df1.loc['a':'c']
# Out:
# 매출항목     A     B     C
# 가게명
# a     2745  4801  4907
# b     1154  8767  9497
# c     6407  2563  3928

# %%
df1.loc[['c','a'],'A']
# Out:
# 가게명
# c    6407
# a    2745
# Name: A, dtype: int64

# %%
df1.loc[['c','a'],['A']]
# Out:
# 매출항목     A
# 가게명
# c     6407
# a     2745

# %%
df1.loc[['c','a'],['C','A']]
# Out:
# 매출항목     C     A
# 가게명
# c     3928  6407
# a     4907  2745

# %%
df1.loc[['c','a'],'A':'C'], df1.loc[['c','a'],'A':'A']
# Out:
# (매출항목     A     B     C
#  가게명
#  c     6407  2563  3928
#  a     2745  4801  4907,
#  매출항목     A
#  가게명
#  c     6407
#  a     2745)

# %%
df1.iloc[-1]
# Out:
# 매출항목
# A    9217
# B    8115
# C    8923
# Name: e, dtype: int64

# %%
df1.iloc[-3:-1]
# Out:
# 매출항목     A     B     C
# 가게명
# c     6407  2563  3928
# d     4405  8246  1718

# %%
df1.iloc[::-1,[1, 2, 0]]
# Out:
# 매출항목     B     C     A
# 가게명
# e     8115  8923  9217
# d     8246  1718  4405
# c     2563  3928  6407
# b     8767  9497  1154
# a     4801  4907  2745

# %%
df1.loc[df1.A > 5000]
# Out:
# 매출항목     A     B     C
# 가게명
# c     6407  2563  3928
# e     9217  8115  8923

# %%
# df1.iloc[df1.A > 5000]  # iloc는 불리언 배열 인덱싱이 안됨!

# %% [markdown]
# ## 갯수 세기

# %%
s
# Out:
# 코드
# A    555555
# B    666666
# C    315425
# D    829995
# E    594727
# F    644557
# G    975540
# H    741387
# I    379926
# Name: 통계, dtype: int64

# %%
len(s), s.count()
# Out:
# (9, 9)

# %%
s[0] = np.nan

# %%
len(s), s.count()  # len(s[s.notnull()])
# Out:
# (9, 8)

# %%
df1, len(df1)  # -> 키 => 열의 이름.
# Out:
# (매출항목     A     B     C
#  가게명
#  a     2745  4801  4907
#  b     1154  8767  9497
#  c     6407  2563  3928
#  d     4405  8246  1718
#  e     9217  8115  8923,
#  5)

# %%
df1.count()
# Out:
# 매출항목
# A    5
# B    5
# C    5
# dtype: int64

# %%
df1.loc['a', 'A'] = np.nan
df1
# Out:
# 매출항목       A     B     C
# 가게명
# a        NaN  4801  4907
# b     1154.0  8767  9497
# c     6407.0  2563  3928
# d     4405.0  8246  1718
# e     9217.0  8115  8923

# %%
df1.count()
# Out:
# 매출항목
# A    4
# B    5
# C    5
# dtype: int64

# %%
df1.count(axis=0)  # 행들을 합쳐서 계산해주겠다
# Out:
# 매출항목
# A    4
# B    5
# C    5
# dtype: int64

# %%
df1.count(axis=1)  # 열들을 합쳐서 계산해주겠다
# Out:
# 가게명
# a    2
# b    3
# c    3
# d    3
# e    3
# dtype: int64

# %%
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
# df.head()  # 상단 5개
df.head(20)  # 상단 20개
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
df.tail()  # 하단 5개
df.tail(10)  # 하단 10개
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe            46.2           14.1              217.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 336  Gentoo  Biscoe            44.5           15.7              217.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  Female
# 335       5850.0    Male
# 336       4875.0     NaN
# 337       6000.0    Male
# 338       4925.0  Female
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()  # float, int
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.describe().columns
# Out:
# Index(['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'], dtype='object')

# %%
df.describe(include='O')  # 계산을 할 수 없는...
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       152     168   168

# %%
df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# top             NaN  Male
# freq            NaN   168
# mean    4201.754386   NaN
# std      801.954536   NaN
# min     2700.000000   NaN
# 25%     3550.000000   NaN
# 50%     4050.000000   NaN
# 75%     4750.000000   NaN
# max     6300.000000   NaN

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
gender = df.sex
type(gender)
# Out:
# pandas.core.series.Series

# %%
gender.value_counts()  # 결측치를 제외하고...
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
gender.nunique() # nan은 안 세줌 (결측치)
# Out:
# 2

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
weight = df.body_mass_g
weight
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339       NaN
# 340    4850.0
# 341    5750.0
# 342    5200.0
# 343    5400.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
weight.sort_values()  # 오름차순 + nan의 위치 (last)
# Out:
# 190    2700.0
# 64     2850.0
# 58     2850.0
# 116    2900.0
# 98     2900.0
#         ...
# 337    6000.0
# 253    6050.0
# 237    6300.0
# 3         NaN
# 339       NaN
# Name: body_mass_g, Length: 344, dtype: float64

# %%
weight.sort_values(ascending=False)  # 내림차순 + nan의 위치 (last)
# Out:
# 237    6300.0
# 253    6050.0
# 297    6000.0
# 337    6000.0
# 331    5950.0
#         ...
# 58     2850.0
# 64     2850.0
# 190    2700.0
# 3         NaN
# 339       NaN
# Name: body_mass_g, Length: 344, dtype: float64

# %%
weight.sort_values(ascending=False, na_position='first')  # 내림차순 + nan의 위치 (first)
# Out:
# 3         NaN
# 339       NaN
# 237    6300.0
# 253    6050.0
# 297    6000.0
#         ...
# 116    2900.0
# 98     2900.0
# 58     2850.0
# 64     2850.0
# 190    2700.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
weight.sort_values(ascending=False).dropna()
# Out:
# 237    6300.0
# 253    6050.0
# 297    6000.0
# 337    6000.0
# 331    5950.0
#         ...
# 116    2900.0
# 98     2900.0
# 58     2850.0
# 64     2850.0
# 190    2700.0
# Name: body_mass_g, Length: 342, dtype: float64

# %%
species = df.species.value_counts()
species
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
species.sort_index()
# Out:
# Adelie       152
# Chinstrap     68
# Gentoo       124
# Name: species, dtype: int64

# %%
species.sort_index(ascending=False)
# Out:
# Gentoo       124
# Chinstrap     68
# Adelie       152
# Name: species, dtype: int64

# %%
species.sort_index(ascending=0)
# Out:
# Gentoo       124
# Chinstrap     68
# Adelie       152
# Name: species, dtype: int64

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df.sort_values(by='flipper_length_mm')  # ...
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 28   Adelie     Biscoe            37.9           18.6              172.0
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 122  Adelie  Torgersen            40.2           17.0              176.0
# 31   Adelie      Dream            37.2           18.1              178.0
# 30   Adelie      Dream            39.5           16.7              178.0
# ..      ...        ...             ...            ...                ...
# 285  Gentoo     Biscoe            49.8           16.8              230.0
# 333  Gentoo     Biscoe            51.5           16.3              230.0
# 283  Gentoo     Biscoe            54.3           15.7              231.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 28        3150.0  Female
# 20        3400.0  Female
# 122       3450.0  Female
# 31        3900.0    Male
# 30        3250.0  Female
# ..           ...     ...
# 285       5700.0    Male
# 333       5500.0    Male
# 283       5650.0    Male
# 3            NaN     NaN
# 339          NaN     NaN
#
# [344 rows x 7 columns]

# %%
df.sort_values(by=['flipper_length_mm', 'bill_depth_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 28   Adelie     Biscoe            37.9           18.6              172.0
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 122  Adelie  Torgersen            40.2           17.0              176.0
# 98   Adelie      Dream            33.1           16.1              178.0
# 30   Adelie      Dream            39.5           16.7              178.0
# ..      ...        ...             ...            ...                ...
# 253  Gentoo     Biscoe            59.6           17.0              230.0
# 309  Gentoo     Biscoe            52.1           17.0              230.0
# 283  Gentoo     Biscoe            54.3           15.7              231.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g     sex
# 28        3150.0  Female
# 20        3400.0  Female
# 122       3450.0  Female
# 98        2900.0  Female
# 30        3250.0  Female
# ..           ...     ...
# 253       6050.0    Male
# 309       5550.0    Male
# 283       5650.0    Male
# 3            NaN     NaN
# 339          NaN     NaN
#
# [344 rows x 7 columns]

# %% [markdown]
# ## 연산

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.sum().tip
# Out:
# <ipython-input-102-82337965bf56>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   tips.sum().tip
# 731.5799999999999

# %%
tips.tip.sum()
# Out:
# 731.5799999999999

# %%
tips.tip.mean()
# Out:
# 2.99827868852459

# %% [markdown]
# ## apply

# %%
tips.tip / tips.total_bill * 100  # 고객당 전체 지불 금액 대비 팁의 비율(%)
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
tips.apply(lambda x: x.tip / x.total_bill * 100, axis=1)
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df.sex.fillna('?').value_counts()  # fill_na -> nan로 두면 못쓰는 경우가 많음...
# Out:
# Male      168
# Female    165
# ?          11
# Name: sex, dtype: int64

# %% [markdown]
# ## 인덱스 조작

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df.set_index('species', inplace=True) # <- 원본에 바로 영향을 미치게 된다

# %%
df
# Out:
#             island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie   Torgersen            39.1           18.7              181.0
# Adelie   Torgersen            39.5           17.4              186.0
# Adelie   Torgersen            40.3           18.0              195.0
# Adelie   Torgersen             NaN            NaN                NaN
# Adelie   Torgersen            36.7           19.3              193.0
# ...            ...             ...            ...                ...
# Gentoo      Biscoe             NaN            NaN                NaN
# Gentoo      Biscoe            46.8           14.3              215.0
# Gentoo      Biscoe            50.4           15.7              222.0
# Gentoo      Biscoe            45.2           14.8              212.0
# Gentoo      Biscoe            49.9           16.1              213.0
#
#          body_mass_g     sex
# species
# Adelie        3750.0    Male
# Adelie        3800.0  Female
# Adelie        3250.0  Female
# Adelie           NaN     NaN
# Adelie        3450.0  Female
# ...              ...     ...
# Gentoo           NaN     NaN
# Gentoo        4850.0  Female
# Gentoo        5750.0    Male
# Gentoo        5200.0  Female
# Gentoo        5400.0    Male
#
# [344 rows x 6 columns]

# %%
df.reset_index()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
df
# Out:
#             island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie   Torgersen            39.1           18.7              181.0
# Adelie   Torgersen            39.5           17.4              186.0
# Adelie   Torgersen            40.3           18.0              195.0
# Adelie   Torgersen             NaN            NaN                NaN
# Adelie   Torgersen            36.7           19.3              193.0
# ...            ...             ...            ...                ...
# Gentoo      Biscoe             NaN            NaN                NaN
# Gentoo      Biscoe            46.8           14.3              215.0
# Gentoo      Biscoe            50.4           15.7              222.0
# Gentoo      Biscoe            45.2           14.8              212.0
# Gentoo      Biscoe            49.9           16.1              213.0
#
#          body_mass_g     sex
# species
# Adelie        3750.0    Male
# Adelie        3800.0  Female
# Adelie        3250.0  Female
# Adelie           NaN     NaN
# Adelie        3450.0  Female
# ...              ...     ...
# Gentoo           NaN     NaN
# Gentoo        4850.0  Female
# Gentoo        5750.0    Male
# Gentoo        5200.0  Female
# Gentoo        5400.0    Male
#
# [344 rows x 6 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
del df['island']

# %%
df.drop('sex', axis=1)
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0    Adelie            39.1           18.7              181.0       3750.0
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 3    Adelie             NaN            NaN                NaN          NaN
# 4    Adelie            36.7           19.3              193.0       3450.0
# ..      ...             ...            ...                ...          ...
# 339  Gentoo             NaN            NaN                NaN          NaN
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
# [344 rows x 5 columns]

# %%
df.drop(0, axis=0)
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 1    Adelie            39.5           17.4              186.0       3800.0
# 2    Adelie            40.3           18.0              195.0       3250.0
# 3    Adelie             NaN            NaN                NaN          NaN
# 4    Adelie            36.7           19.3              193.0       3450.0
# 5    Adelie            39.3           20.6              190.0       3650.0
# ..      ...             ...            ...                ...          ...
# 339  Gentoo             NaN            NaN                NaN          NaN
# 340  Gentoo            46.8           14.3              215.0       4850.0
# 341  Gentoo            50.4           15.7              222.0       5750.0
# 342  Gentoo            45.2           14.8              212.0       5200.0
# 343  Gentoo            49.9           16.1              213.0       5400.0
#
#         sex
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# 5      Male
# ..      ...
# 339     NaN
# 340  Female
# 341    Male
# 342  Female
# 343    Male
#
# [343 rows x 6 columns]
